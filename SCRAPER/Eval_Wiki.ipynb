# %% [markdown]
# # Evaluación inicial.
#
# ## wikipedia
#
# En el presente notebook llevaremos a cabo la evaluación inicial de la página web donde realizaremos parte de nuestro web scraping. La web con la que trabajaremos es la conocida https://es.wikipedia.org y su enlace es el siguiente:
# * https://es.wikipedia.org/wiki/Anexo:Votaci%C3%B3n_del_MVP_de_la_NBA_2018-19

# %% [markdown]
# ### 1. Archivo _robots.txt_

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://es.wikipedia.org/wiki/Anexo:Votaci%C3%B3n_del_MVP_de_la_NBA_2018-19'

response = requests.get(url) 
html_soup = BeautifulSoup(response.text, "lxml")
html_soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="es">
# <head>
# <meta charset="utf-8"/>
# <title>Anexo:Votación del MVP de la NBA 2018-19 - Wikipedia, la enciclopedia libre</title>
# ...

# %% [markdown]
# ### 2. Mapa del sitio web
#
# Con el comando "ctrl + u" podemos acceder al mapa del sitio web.

# %% [markdown]
# ### 3. Tamaño
#
# La búsqueda en Google de 'https://es.wikipedia.org' nos devuelve un total de 1.010.000.000 resultados. En nuestro web scraping usaremos directamente el enlace que nos redirecciona a las votaciones del mvp de cada año ('https://es.wikipedia.org/wiki/Anexo:Votaci%C3%B3n_del_MVP_de_la_NBA_2018-19', variando el año) permitiéndonos realizar cada búsqueda de forma más óptima.

# %% [markdown]
# ### 4. Tecnología
#
# Indicamos la tecnología empleada en el desarrollo de la página web.

# %%
import builtwith
builtwith.builtwith('https://es.wikipedia.org')
# Out:
# {'wikis': ['MediaWiki']}

# %% [markdown]
# ### 5. Propietario
#
# Indicamos el propietario de la página web

# %%
import whois
whois.whois('https://es.wikipedia.org')
# Out:
# {'address': None,
#  'city': None,
#  'country': 'US',
#  'creation_date': [datetime.datetime(2001, 1, 13, 0, 12, 14),
#   datetime.datetime(2001, 1, 12, 16, 12, 14)],
#  'dnssec': 'unsigned',
#  'domain_name': ['WIKIPEDIA.ORG', 'wikipedia.org'],
#  'emails': ['abusecomplaints@markmonitor.com', 'whoisrequest@markmonitor.com'],
#  'expiration_date': [datetime.datetime(2023, 1, 13, 0, 12, 14),
#   datetime.datetime(2023, 1, 12, 0, 0)],
#  'name': None,
#  'name_servers': ['NS0.WIKIMEDIA.ORG',
#   'NS1.WIKIMEDIA.ORG',
#   'NS2.WIKIMEDIA.ORG',
#   'ns1.wikimedia.org',
#   'ns0.wikimedia.org',
#   'ns2.wikimedia.org'],
#  'org': 'Wikimedia Foundation, Inc.',
#  'referral_url': None,
#  'registrar': 'MarkMonitor, Inc.',
#  'state': 'CA',
#  'status': ['clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited',
#   'clientTransferProhibited https://icann.org/epp#clientTransferProhibited',
#   'clientUpdateProhibited https://icann.org/epp#clientUpdateProhibited',
# ...
